# %% [markdown]
# # CSI4142 - Fundamentals of Data Science
# # Assignment 2: Data Cleaning
#
# **Student 1:** Peter Bou-Farah - 300295193
# **Student 2:** Martin Patrouchev - 300286634
#
# ### Work Split
# - **Peter:** TODO
# - **Martin:** TODO

# %% [markdown]
# ---
# # DATASET 1: [Dataset Name Here] (Validity Checking)
# ---

# %% [markdown]
# ## 1. Dataset 1 Description
#
# ### Overview
# - **Dataset Name:** TODO
# - **Author:** TODO
# - **Source:** [TODO - Link to dataset](URL) | [TODO - Kaggle link](URL)
# - **Purpose:** TODO - What was this dataset made for? (must NOT be synthetic)
#
# ### Shape
# - **Rows:** TODO
# - **Columns:** TODO
#
# ### Features Description
#
# | Feature | Type | Description |
# |---------|------|-------------|
# | TODO | Numerical/Categorical | TODO |
# | TODO | Numerical/Categorical | TODO |

# %% [markdown]
# ## 2. Setup and Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Loading Dataset 1

# %%
# Load Dataset 1 from a public URL (so TAs can run without downloading)
url_ds1 = "TODO_REPLACE_WITH_PUBLIC_URL"
df1_original = pd.read_csv(url_ds1)

# Keep a copy of the original for comparison
df1 = df1_original.copy()

# Display basic information
print("Dataset Shape:", df1.shape)
print("\nFirst 5 rows:")
df1.head()

# %%
# Dataset information and data types
print("Dataset Info:")
print("=" * 50)
df1.info()
print("\n" + "=" * 50)
print("\nStatistical Summary (Numerical Features):")
df1.describe()

# %% [markdown]
# ---
# ## 4. Validity Checker
#
# In this section, we implement a validity checker that detects 8 types of invalid data. For each validity test, we:
# 1. Describe the error type
# 2. Introduce ~5% of errors into the dataset
# 3. Run the checker code to detect the errors
# 4. Report qualitative findings with before/after examples
#
# ---

# %% [markdown]
# ### 4.1 Data Type Errors
#
# **Description:** Data type errors occur when a value does not match the expected data type for a column. For example, a string appearing in a column that should contain only integers, or a float in a column expected to hold categorical labels.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% data type errors.

# %%
# --- Cell 2: Introduce Data Type Errors ---
# TODO: Code to introduce ~5% data type errors into a chosen column
# Example: Replace 5% of numeric values in a column with string values

# %%
# --- Cell 3: Checker Code for Data Type Errors ---
# TODO: Code to automatically detect data type errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.2 Range Errors
#
# **Description:** Range errors occur when a numerical value falls outside the valid minimum and maximum bounds for that attribute. For example, an age value of -5 or 200 when valid ages are 0-120.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% range errors.

# %%
# --- Cell 2: Introduce Range Errors ---
# TODO: Code to introduce ~5% range errors into a chosen column

# %%
# --- Cell 3: Checker Code for Range Errors ---
# TODO: Code to automatically detect range errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.3 Format Errors
#
# **Description:** Format errors occur when a value does not follow the expected pattern or format. For example, a date written as "2024/31/12" instead of "YYYY-MM-DD", or an email address missing the "@" symbol.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% format errors.

# %%
# --- Cell 2: Introduce Format Errors ---
# TODO: Code to introduce ~5% format errors into a chosen column

# %%
# --- Cell 3: Checker Code for Format Errors ---
# TODO: Code to automatically detect format errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.4 Consistency Errors
#
# **Description:** Consistency errors occur when values across multiple columns contradict each other. For example, a city that does not match its corresponding postal code, or a "date of birth" that is after the "date of enrollment".

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which columns you targeted and how you introduced ~5% consistency errors.

# %%
# --- Cell 2: Introduce Consistency Errors ---
# TODO: Code to introduce ~5% consistency errors

# %%
# --- Cell 3: Checker Code for Consistency Errors ---
# TODO: Code to automatically detect consistency errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.5 Uniqueness Errors
#
# **Description:** Uniqueness errors occur when duplicate values appear in a column that should contain only unique entries. For example, duplicate IDs in a primary key column, or duplicate email addresses in a registration dataset.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% uniqueness errors.

# %%
# --- Cell 2: Introduce Uniqueness Errors ---
# TODO: Code to introduce ~5% uniqueness errors into a chosen column

# %%
# --- Cell 3: Checker Code for Uniqueness Errors ---
# TODO: Code to automatically detect uniqueness errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.6 Presence Errors
#
# **Description:** Presence errors occur when required fields contain missing or null values. For example, a mandatory "name" column containing NaN entries, or an empty string in a required field.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% presence errors.

# %%
# --- Cell 2: Introduce Presence Errors ---
# TODO: Code to introduce ~5% presence errors (NaN/null) into a chosen column

# %%
# --- Cell 3: Checker Code for Presence Errors ---
# TODO: Code to automatically detect presence errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.7 Length Errors
#
# **Description:** Length errors occur when string values are too short or too long for the expected format. For example, a phone number with only 5 digits instead of 10, or a postal code that is 3 characters instead of 6.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% length errors.

# %%
# --- Cell 2: Introduce Length Errors ---
# TODO: Code to introduce ~5% length errors into a chosen column

# %%
# --- Cell 3: Checker Code for Length Errors ---
# TODO: Code to automatically detect length errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# ### 4.8 Look-up Errors
#
# **Description:** Look-up errors occur when a value does not belong to a predefined set of allowed values. For example, a "country" column containing "Atlantis" which is not a real country, or a "gender" column containing "X" when only "M" and "F" are valid.

# %% [markdown]
# **How we introduced the error:**
#
# TODO - Describe which column you targeted and how you introduced ~5% look-up errors.

# %%
# --- Cell 2: Introduce Look-up Errors ---
# TODO: Code to introduce ~5% look-up errors into a chosen column

# %%
# --- Cell 3: Checker Code for Look-up Errors ---
# TODO: Code to automatically detect look-up errors

# %% [markdown]
# **Qualitative Results:**
#
# TODO - Show 3 before/after examples and explain findings.

# %% [markdown]
# ---
# # DATASET 2: [Dataset Name Here] (Imputation)
# ---

# %% [markdown]
# ## 5. Dataset 2 Description
#
# ### Overview
# - **Dataset Name:** TODO
# - **Author:** TODO
# - **Source:** [TODO - Link to dataset](URL) | [TODO - Kaggle link](URL)
# - **Purpose:** TODO - What was this dataset made for? (must NOT be synthetic)
#
# ### Shape
# - **Rows:** TODO
# - **Columns:** TODO
#
# ### Features Description
#
# | Feature | Type | Description |
# |---------|------|-------------|
# | TODO | Numerical/Categorical | TODO |
# | TODO | Numerical/Categorical | TODO |

# %% [markdown]
# ## 6. Loading Dataset 2

# %%
# Load Dataset 2 from a public URL (so TAs can run without downloading)
url_ds2 = "TODO_REPLACE_WITH_PUBLIC_URL"
df2_original = pd.read_csv(url_ds2)

# Keep a copy of the original for evaluation
df2 = df2_original.copy()

# Display basic information
print("Dataset Shape:", df2.shape)
print("\nFirst 5 rows:")
df2.head()

# %%
# Dataset information and data types
print("Dataset Info:")
print("=" * 50)
df2.info()
print("\n" + "=" * 50)
print("\nStatistical Summary (Numerical Features):")
df2.describe()

# %% [markdown]
# ---
# ## 7. Missing Data and Imputation
#
# In this section, we perform 3 imputation experiments, each on a different attribute using a different imputation method. For each test, we:
# 1. Describe the imputation method
# 2. Simulate missing values (specifying MCAR, MAR, or MNAR)
# 3. Implement the imputation approach
# 4. Quantitatively evaluate the results
#
# ---

# %% [markdown]
# ### 7.1 Imputation Test 1: [Method Name Here] (Univariate)
#
# **Description:** TODO - Describe the imputation method (e.g., Default Value Imputation using median). Explain when this method is appropriate and its assumptions.

# %% [markdown]
# **How we introduced missing data:**
#
# - **Column:** TODO
# - **Missingness type:** TODO (MCAR / MAR / MNAR)
# - **Explanation:** TODO - Describe how you removed values and why this simulates the chosen missingness type.

# %%
# --- Cell 2: Introduce Missing Data for Test 1 ---
# TODO: Code to remove values from the chosen column

# %%
# --- Cell 3: Imputation Code for Test 1 ---
# TODO: Code to detect missing values and impute them

# %% [markdown]
# **Quantitative Evaluation:**
#
# TODO - Evaluate imputation quality using metrics (e.g., RMSE, MAE, comparison of distributions before/after).

# %%
# --- Cell 4: Evaluation Code for Test 1 ---
# TODO: Compute evaluation metrics comparing imputed values to original values

# %% [markdown]
# ---
# ### 7.2 Imputation Test 2: [Method Name Here] (Bivariate)
#
# **Description:** TODO - Describe the imputation method (e.g., Regression Imputation). Explain when this method is appropriate and its assumptions.

# %% [markdown]
# **How we introduced missing data:**
#
# - **Column:** TODO
# - **Missingness type:** TODO (MCAR / MAR / MNAR)
# - **Explanation:** TODO - Describe how you removed values and why this simulates the chosen missingness type.

# %%
# --- Cell 2: Introduce Missing Data for Test 2 ---
# TODO: Code to remove values from the chosen column

# %%
# --- Cell 3: Imputation Code for Test 2 ---
# TODO: Code to detect missing values and impute them

# %% [markdown]
# **Quantitative Evaluation:**
#
# TODO - Evaluate imputation quality using metrics.

# %%
# --- Cell 4: Evaluation Code for Test 2 ---
# TODO: Compute evaluation metrics comparing imputed values to original values

# %% [markdown]
# ---
# ### 7.3 Imputation Test 3: [Method Name Here] (Multivariate)
#
# **Description:** TODO - Describe the imputation method (e.g., Similarity-based / KNN Imputation). Explain when this method is appropriate and its assumptions.

# %% [markdown]
# **How we introduced missing data:**
#
# - **Column:** TODO
# - **Missingness type:** TODO (MCAR / MAR / MNAR)
# - **Explanation:** TODO - Describe how you removed values and why this simulates the chosen missingness type.

# %%
# --- Cell 2: Introduce Missing Data for Test 3 ---
# TODO: Code to remove values from the chosen column

# %%
# --- Cell 3: Imputation Code for Test 3 ---
# TODO: Code to detect missing values and impute them

# %% [markdown]
# **Quantitative Evaluation:**
#
# TODO - Evaluate imputation quality using metrics.

# %%
# --- Cell 4: Evaluation Code for Test 3 ---
# TODO: Compute evaluation metrics comparing imputed values to original values

# %% [markdown]
# ---
# ## 8. References
#
# ### Datasets
# 1. TODO - Dataset 1 reference
# 2. TODO - Dataset 2 reference
#
# ### Libraries and Documentation
# 3. Pandas Development Team. (2026). pandas documentation. https://pandas.pydata.org/docs/
# 4. Matplotlib Development Team. (2026). Matplotlib documentation. https://matplotlib.org/stable/
# 5. Seaborn Development Team. (2026). Seaborn documentation. https://seaborn.pydata.org/
#
# ### AI Assistance
# - TODO - List any AI tools used and the prompts/queries for each code snippet.
#
# ### Other References
# - TODO - Any theory, algorithms, tutorials, StackOverflow, etc.
